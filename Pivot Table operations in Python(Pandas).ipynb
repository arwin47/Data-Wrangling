# %% [markdown]
# ### Creating a pivot table from dataframe

# %%
import pandas as pd
import numpy as np

dataf = pd.DataFrame({'fff': ['one', 'one', 'one', 'two', 'two',
                           'two'],
                   'bbb': ['P', 'Q', 'R', 'P', 'Q', 'R'],
                   'baa': [2, 3, 4, 5, 6, 7],
                   'zzz': ['h', 'i', 'j', 'k', 'l', 'm']})
dataf
# Out:
#    fff bbb  baa zzz
# 0  one   P    2   h
# 1  one   Q    3   i
# 2  one   R    4   j
# 3  two   P    5   k
# 4  two   Q    6   l
# 5  two   R    7   m

# %%
dataf.pivot(index='fff', columns='bbb', values='baa')
# Out:
# bbb  P  Q  R
# fff
# one  2  3  4
# two  5  6  7

# %%
# Another method of setting values
dataf.pivot(index='fff', columns='bbb')['baa']
# Out:
# bbb  P  Q  R
# fff
# one  2  3  4
# two  5  6  7

# %% [markdown]
# ### Multiple values

# %%
dataf.pivot(index='fff', columns='bbb', values=['baa', 'zzz'])
# Out:
#     baa       zzz
# bbb   P  Q  R   P  Q  R
# fff
# one   2  3  4   h  i  j
# two   5  6  7   k  l  m

# %%
data = pd.read_csv(r"..\living_costs.csv")

#Data Source: https://www.stats.govt.nz/large-datasets/csv-files-for-download/

# %%
data.head()
# Out:
#         hlpi_name  year   hlpi nzhec               nzhec_name   nzhec_short  \
# 0  All households  2008  allhh     1                     Food          Food
# 1  All households  2008  allhh   1.1     Fruit and vegetables   Fruit & veg
# 2  All households  2008  allhh   1.2   Meat, poultry and fish          Meat
# 3  All households  2008  allhh   1.3             Grocery food  Grocery food
# 4  All households  2008  allhh   1.4  Non-alcoholic beverages   Soft drinks
#
#       level  nzhec1 nzhec1_name nzhec1_short  weight  exp_pw  eqv_exp_pw
# 0     group       1        Food         Food    18.0   146.4        86.8
# 1  subgroup       1        Food         Food     2.6    21.1        12.5
# 2  subgroup       1        Food         Food     3.1    25.2        14.9
# 3  subgroup       1        Food         Food     7.4    60.2        35.7
# 4  subgroup       1        Food         Food     1.7    13.8         8.2

# %% [markdown]
# ### Multiple Indices

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"]).head() # values are automatically taken from numeric features
# Out:
#                                                                  eqv_exp_pw  \
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages               22.233857
#                                 Alcoholic beverages and tobacco   36.033429
#                                 Cigarettes and tobacco            13.765286
# Clothing and footwear           Clothing                          15.271571
#                                 Clothing and footwear             18.702571
#
#                                                                     exp_pw  \
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              37.272429
#                                 Alcoholic beverages and tobacco  60.438571
#                                 Cigarettes and tobacco           23.093286
# Clothing and footwear           Clothing                         25.680429
#                                 Clothing and footwear            31.443571
#
#                                                                  nzhec1  \
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                   2
#                                 Alcoholic beverages and tobacco       2
#                                 Cigarettes and tobacco                2
# Clothing and footwear           Clothing                              3
#                                 Clothing and footwear                 3
#
#                                                                    weight  \
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              3.612245
#                                 Alcoholic beverages and tobacco  6.545918
#                                 Cigarettes and tobacco           2.929592
# Clothing and footwear           Clothing                         2.419388
#                                 Clothing and footwear            2.952041
#
#                                                                         year
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              2016.142857
#                                 Alcoholic beverages and tobacco  2016.142857
#                                 Cigarettes and tobacco           2016.142857
# Clothing and footwear           Clothing                         2016.142857
#                                 Clothing and footwear            2016.142857

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"]).head()
# Out:
#                                                                    weight
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              3.612245
#                                 Alcoholic beverages and tobacco  6.545918
#                                 Cigarettes and tobacco           2.929592
# Clothing and footwear           Clothing                         2.419388
#                                 Clothing and footwear            2.952041

# %% [markdown]
# ### Defining aggregation

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],aggfunc=np.sum).head()
# Out:
#                                                                  weight
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages               354.0
#                                 Alcoholic beverages and tobacco   641.5
#                                 Cigarettes and tobacco            287.1
# Clothing and footwear           Clothing                          237.1
#                                 Clothing and footwear             289.3

# %% [markdown]
# #### Finding unique values

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],aggfunc=[np.sum, pd.Series.nunique]).head()
# Out:
#                                                                    sum nunique
#                                                                 weight  weight
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              354.0    36.0
#                                 Alcoholic beverages and tobacco  641.5    34.0
#                                 Cigarettes and tobacco           287.1    40.0
# Clothing and footwear           Clothing                         237.1    26.0
#                                 Clothing and footwear            289.3    38.0

# %% [markdown]
# ### Multiple aggregations

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],aggfunc=[np.mean,len]).head()
# Out:
#                                                                      mean  \
#                                                                    weight
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages              3.612245
#                                 Alcoholic beverages and tobacco  6.545918
#                                 Cigarettes and tobacco           2.929592
# Clothing and footwear           Clothing                         2.419388
#                                 Clothing and footwear            2.952041
#
#                                                                    len
#                                                                 weight
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages               98.0
#                                 Alcoholic beverages and tobacco   98.0
#                                 Cigarettes and tobacco            98.0
# Clothing and footwear           Clothing                          98.0
#                                 Clothing and footwear             98.0

# %% [markdown]
# ### Adding columns

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],columns=["level"],aggfunc=[np.sum]).head()
# Out:
#                                                                    sum         \
#                                                                 weight
# level                                                            class  group
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                NaN    NaN
#                                 Alcoholic beverages and tobacco    NaN  641.5
#                                 Cigarettes and tobacco             NaN    NaN
# Clothing and footwear           Clothing                           NaN    NaN
#                                 Clothing and footwear              NaN  289.3
#
#
#
# level                                                           subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                354.0
#                                 Alcoholic beverages and tobacco      NaN
#                                 Cigarettes and tobacco             287.1
# Clothing and footwear           Clothing                           237.1
#                                 Clothing and footwear                NaN

# %% [markdown]
# ### Filling NaN in pivots

# %%
pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],columns=["level"],aggfunc=[np.sum], fill_value=0).head()
# Out:
#                                                                    sum         \
#                                                                 weight
# level                                                            class  group
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                0.0    0.0
#                                 Alcoholic beverages and tobacco    0.0  641.5
#                                 Cigarettes and tobacco             0.0    0.0
# Clothing and footwear           Clothing                           0.0    0.0
#                                 Clothing and footwear              0.0  289.3
#
#
#
# level                                                           subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                354.0
#                                 Alcoholic beverages and tobacco      0.0
#                                 Cigarettes and tobacco             287.1
# Clothing and footwear           Clothing                           237.1
#                                 Clothing and footwear                0.0

# %% [markdown]
# ### Querying pivot table

# %%
pivot1 = pd.pivot_table(data,index=["nzhec1_name","nzhec_name"],values=["weight"],columns=["level"],aggfunc=[np.sum], fill_value=0).head()


pivot1.query('nzhec1_name == ["Clothing and footwear"]')
# Out:
#                                                sum
#                                             weight
# level                                        class  group subgroup
# nzhec1_name           nzhec_name
# Clothing and footwear Clothing                 0.0    0.0    237.1
#                       Clothing and footwear    0.0  289.3      0.0

# %%
pivot1.query('nzhec_name == ["Clothing"]')
# Out:
#                                     sum
#                                  weight
# level                             class group subgroup
# nzhec1_name           nzhec_name
# Clothing and footwear Clothing      0.0   0.0    237.1

# %% [markdown]
# ### Unpivot
#
# **Arguments:**
#
# **id_vars:** identifies the column to be used as identifier variables
#
# **value_vars:** the columns to unpivot. Which, if empty, (as is the case here), uses all columns except those identified in id_vars
#
# **var_name:** assigns a name to the columns that were unpivoted
#
# **value_name:** assigns a name to to the value column

# %%
df_unpivot = pd.read_excel(r'..\unpivot.xlsx')
df_unpivot.head()
# Out:
#     Product  Quarter 1  Quarter 2  Quarter 3  Quarter 4
# 0    Apples       1682        993       1203       1984
# 1   Bananas        852       1321        243       3427
# 2     Bread        192       1767       2853       1937
# 3  Brocolli       2363       2703       2403       1302
# 4   Oranges        286       1703        148       1254

# %%
df_unpivot.melt(id_vars = 'Product', var_name = 'Quarter', value_name = 'Sales').head()
# Out:
#     Product    Quarter  Sales
# 0    Apples  Quarter 1   1682
# 1   Bananas  Quarter 1    852
# 2     Bread  Quarter 1    192
# 3  Brocolli  Quarter 1   2363
# 4   Oranges  Quarter 1    286

# %% [markdown]
# ### Viewing multilevel indices in pivot

# %%
pivot1.index.levels
# Out:
# FrozenList([['Alcoholic beverages and tobacco', 'Clothing and footwear', 'Communication', 'Education', 'Food', 'Health', 'Household contents and services', 'Housing and household utilities', 'Miscellaneous goods and services', 'Other expenditure', 'Recreation and culture', 'Transport'], ['Accommodation services', 'Actual rentals for housing', 'Alcoholic beverages', 'Alcoholic beverages and tobacco', 'Audio-visual and computing equipment', 'Cigarettes and tobacco', 'Clothing', 'Clothing and footwear', 'Communication', 'Credit services', 'Early childhood education', 'Education', 'Electricity', 'Food', 'Footwear', 'Fruit and vegetables', 'Furniture, furnishings and floor coverings', 'Glassware, tableware and household utensils', 'Grocery food', 'Health', 'Hospital services', 'Household appliances', 'Household contents and services', 'Household energy', 'Household textiles', 'Housing and household utilities', 'Insurance', 'Interest payments', 'Local authority rates and payments', 'Major recreational and cultural equipment', 'Meat, poultry and fish', 'Medical products, appliances and equipment', 'Miscellaneous goods and services', 'Newspapers, books and stationery', 'Non-alcoholic beverages', 'Other educational fees', 'Other expenditure', 'Other household supplies and services', 'Other miscellaneous services', 'Other recreational equipment and supplies', 'Out-patient services', 'Package holidays', 'Passenger transport services', 'Personal care', 'Personal effects', 'Petrol', 'Postal services', 'Primary and secondary education', 'Private transport supplies and services', 'Property maintenance', 'Property rates and related services', 'Purchase of vehicles', 'Recreation and culture', 'Recreational and cultural services', 'Restaurant meals and ready-to-eat food', 'Telecommunication equipment', 'Telecommunication services', 'Tertiary and other post school education', 'Tools and equipment for house and garden', 'Transport']])

# %% [markdown]
# ### Dropping levels in columns
#
# using droplevel and setting axis =1

# %%
pivot1.head()
# Out:
#                                                                    sum         \
#                                                                 weight
# level                                                            class  group
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                0.0    0.0
#                                 Alcoholic beverages and tobacco    0.0  641.5
#                                 Cigarettes and tobacco             0.0    0.0
# Clothing and footwear           Clothing                           0.0    0.0
#                                 Clothing and footwear              0.0  289.3
#
#
#
# level                                                           subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                354.0
#                                 Alcoholic beverages and tobacco      0.0
#                                 Cigarettes and tobacco             287.1
# Clothing and footwear           Clothing                           237.1
#                                 Clothing and footwear                0.0

# %%
pivot1.head().droplevel([0], axis = 1)
# Out:
#                                                                 weight         \
# level                                                            class  group
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                0.0    0.0
#                                 Alcoholic beverages and tobacco    0.0  641.5
#                                 Cigarettes and tobacco             0.0    0.0
# Clothing and footwear           Clothing                           0.0    0.0
#                                 Clothing and footwear              0.0  289.3
#
#
# level                                                           subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                354.0
#                                 Alcoholic beverages and tobacco      0.0
#                                 Cigarettes and tobacco             287.1
# Clothing and footwear           Clothing                           237.1
#                                 Clothing and footwear                0.0

# %%
pivot1.head().droplevel([0,1], axis = 1)
# Out:
# level                                                            class  group  \
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                0.0    0.0
#                                 Alcoholic beverages and tobacco    0.0  641.5
#                                 Cigarettes and tobacco             0.0    0.0
# Clothing and footwear           Clothing                           0.0    0.0
#                                 Clothing and footwear              0.0  289.3
#
# level                                                            subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                 354.0
#                                 Alcoholic beverages and tobacco       0.0
#                                 Cigarettes and tobacco              287.1
# Clothing and footwear           Clothing                            237.1
#                                 Clothing and footwear                 0.0

# %% [markdown]
# ### Dropping row indices
#
# using droplevel and setting axis =0

# %%
pivot1.head().droplevel([0], axis = 0)
# Out:
#                                    sum
#                                 weight
# level                            class  group subgroup
# nzhec_name
# Alcoholic beverages                0.0    0.0    354.0
# Alcoholic beverages and tobacco    0.0  641.5      0.0
# Cigarettes and tobacco             0.0    0.0    287.1
# Clothing                           0.0    0.0    237.1
# Clothing and footwear              0.0  289.3      0.0

# %% [markdown]
# ### Accessing multi-index pivots

# %%
pivot1.head()
# Out:
#                                                                    sum         \
#                                                                 weight
# level                                                            class  group
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                0.0    0.0
#                                 Alcoholic beverages and tobacco    0.0  641.5
#                                 Cigarettes and tobacco             0.0    0.0
# Clothing and footwear           Clothing                           0.0    0.0
#                                 Clothing and footwear              0.0  289.3
#
#
#
# level                                                           subgroup
# nzhec1_name                     nzhec_name
# Alcoholic beverages and tobacco Alcoholic beverages                354.0
#                                 Alcoholic beverages and tobacco      0.0
#                                 Cigarettes and tobacco             287.1
# Clothing and footwear           Clothing                           237.1
#                                 Clothing and footwear                0.0

# %%
pivot1.loc['Clothing and footwear', :]
# Out:
#                          sum
#                       weight
# level                  class  group subgroup
# nzhec_name
# Clothing                 0.0    0.0    237.1
# Clothing and footwear    0.0  289.3      0.0

# %%
pivot1.loc['Clothing and footwear', 'Clothing']
# Out:
#              level
# sum  weight  class         0.0
#              group         0.0
#              subgroup    237.1
# Name: (Clothing and footwear, Clothing), dtype: float64

# %%
pivot1.loc['Clothing and footwear']['sum']
# Out:
#                       weight
# level                  class  group subgroup
# nzhec_name
# Clothing                 0.0    0.0    237.1
# Clothing and footwear    0.0  289.3      0.0

# %%
pivot1.loc['Clothing and footwear']['sum']['weight']
# Out:
# level                  class  group  subgroup
# nzhec_name
# Clothing                 0.0    0.0     237.1
# Clothing and footwear    0.0  289.3       0.0
